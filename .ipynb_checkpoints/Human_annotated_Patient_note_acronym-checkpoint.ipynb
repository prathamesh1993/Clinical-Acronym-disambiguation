# %%
from gensim.models import KeyedVectors
import pandas as pd
import numpy as np
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
pd.set_option('display.max_colwidth', -1)
np.set_printoptions(threshold=np.nan)
pd.options.display.max_rows = 999

# %%
model = KeyedVectors.load_word2vec_format('PubMed-shuffle-win-30.bin', binary=True)

# %%
def sentence_vector(sentence):
    word_list = sentence.split()
    #stemmer = SnowballStemmer("english", ignore_stopwords=True)
    #word_list = [stemmer.stem(x) for x in word_list]
    word_list = [word for word in word_list if word not in stop_words]
    
    word_vectors = []
    for x in word_list:
        try:
            word_vectors.append(model[x])
        except KeyError:
            None    
    return sum(word_vectors)/len(word_vectors)
def vector_breakage(sentence):
    word_list = sentence.split()
    #stemmer = SnowballStemmer("english", ignore_stopwords=True)
    #word_list = [stemmer.stem(x) for x in word_list]
    word_list = [word for word in word_list if word not in stop_words]
    word_vectors_list = []
    for x in word_list:
        try:
            if len(model[x])==200:
                word_vectors_list.append(x)
        except:
            None
        else:
            None
    return word_vectors_list

# %%
stop_words = "disease, diseases, disorder, symptom, symptoms, drug, drugs, problems, problem,prob, probs, med, meds,\
, pill, pills, medicine, medicines, medication, medications, treatment, treatments, caps, capsules, capsule,\
, tablet, tablets, tabs, doctor, dr, dr., doc, physician, physicians, test, tests, testing, specialist, specialists,\
, side-effect, side-effects, patient, patients, pharmaceutical, pharmaceuticals, pharma, diagnosis, diagnose, diagnosed, exam,\
, challenge, device, condition, conditions, suffer, suffering ,suffered, feel, feeling, prescription, prescribe,\
, prescribed, over-the-counter, a, about, above, after, again, against, all, am, an, and, any, are, aren't, as, at, be, because, been, before,\
, being, below, between, both, but, by, can, can't, cannot, could, couldn't, did, didn't, do, does, doesn't,\
, doing, don't, down, during, each, few, for, from, further, had, hadn't, has, hasn't, have, haven't, having, he,\
, he'd, he'll, he's, her, here, here's, hers, herself, him, himself, his, how, how's, i, i'd, i'll, i'm, i've, if, in, into,\
, is, isn't, it, it's, its, itself, let's, me, more, most, mustn't, my, myself, no, nor, not, of, off, on, once, only, or,\
, other, ought, our, ours , ourselves, out, over, own, same, shan't, she, she'd, she'll, she's, should, shouldn't,\
, so, some, such, than, that, that's, the, their, theirs, them, themselves, then, there, there's, these, they,\
, they'd, they'll, they're, they've, this, those, through, to, too, under, until, up, very, was, wasn't, we, we'd,\
, we'll, we're, we've, were, weren't, what, what's, when, when's, where, where's, which, while, who, who's,\
, whom, why, why's, with, won't, would, wouldn't, you, you'd, you'll, you're, you've, your, yours, yourself,\
, yourselves, n't, 're, 've, 'd, 's, 'll, 'm".replace(',','').split(' ')

# %%
df = pd.read_csv("Data/PatientNotes_acronym_longform.csv")
group_df = df[['abbreviation','long_form']]
group_df = group_df.groupby('abbreviation').agg(lambda x: set(x.tolist()))
group_df
# Out:
#                                                                                                                                                                                                                                                                                                      long_form
# abbreviation
# AB            {arteriovenous:AV, ankle-brachial, type A, type B, arterial blood, blood group in ABO system, abortion, antipyrine benzocaine, atrioventricular:AV, MISTAKE:abduction, UNSURED SENSE, NAME, X-ray finding}
# AC            {acromioclavicular, acetate, before meals, anticoagulation, alternating current, abdominal circumference, (drug) AC, angiotensin-converting enzyme:ACE, antecubital, adriamycin cyclophosphamide, assist control}
# ALD           {ad lib on demand, alanine aminotransferase:ALT, left anterior descending:LAD, adrenoleukodystrophy, acetyl lysergic acid diethylamide}
# AMA           {advanced maternal age, antimitochondrial antibody, against medical advice}
# ASA           {acetylsalicylic acid, American Society of Anesthesiologists, aminosalicylic acid}
# AV            {atrioventricular, UNSURED SENSE, aortic valve, arteriovenous}
# AVR           {auditory brainstem response:ABR, aortic valve regurgitation, UNSURED SENSE, rapid ventricular response:RVR, aortic valve resistance, aortic valve replacement, augmented voltage right arm}
# BAL           {blood alcohol level, bronchoalveolar lavage}
# BK            {BK (virus), below knee}
# BM            {bone marrow, bowel movement, breast milk, UNSURED SENSE}
# BMP           {bone morphogenetic protein, beta-natriuretic peptide:BNP, basic metabolic profile, bone marrow transplant:BMT}
# C&S           {protein C and protein S, conjunctivae and sclerae, carcinosarcoma:CaS, central nervous system:CNS, culture and sensitivity}
# C3            {(stage) C3, propionylcarnitine, cervical (level) 3, (complement) component 3}
# C4            {(PO Box) C4, fourth heart sound:S4, cervical (level) 4, (complement) component 4, cluster of differentiation 4:CD4}
# CA            {California, UNSURED SENSE, carbohydrate antigen, cancer}
# CDI           {Children's Depression Inventory, UNSURED SENSE, clean, dry, intact, center for diagnostic imaging}
# CEA           {cerebrovascular accident:CVA, cancer:CA, carcinoembryonic antigen, UNSURED SENSE, carotid endarterectomy}
# CR            {C-reactive, complete remission, closed reduction, cardiorespiratory, controlled release, creatinine}
# CTA           {cerebellopontine angle:CPA, creatine phosphokinase:CPK, computed tomographic angiography, UNSURED SENSE, clear to auscultation}
# CVA           {cerebrovascular accident, costovertebral angle}
# CVP           {cyclophosphamide, vincristine, prednisone, cardiovascular pulmonary, central venous pressure}
# CVS           {chorionic villus sampling, customer, value, service, cardiovascular system}
# DC            {District of Columbia, discharge, deceased donor:DD, (drug) DC, discontinue, direct current, (diltiazem) DC, direct and consensual}
# DIP           {distal interphalangeal, dipropionate, desquamative interstitial pneumonia}
# DM            {diabetes mellitus, medical doctor:MD, dextromethorphan, UNSURED SENSE, NAME}
# DT            {deep vein thrombosis:DVT, (drug) DT, delirium tremens, dorsalis pedis:DP, diphtheria-tetanus, doppler echo:DE, physical therapy:PT, UNSURED SENSE}
# EC            {MISTAKE:EZ PAP, extensor carpi, enteric-coated, epirubicin, enterocutaneous, UNSURED SENSE}
# ER            {estrogen receptor, extended release, emergency room}
# ES            {ejection fraction:EF, extra strength, erythrocyte sedimentation rate:ESR, enhanced sensitivity, (drug) ES, UNSURED SENSE}
# ET            {enterostomal therapy, electrophysiology:EP, endotracheal, elective termination, electroconvulsive therapy:ECT, enterocutaneous:EC, UNSURED SENSE, pressure equalization:PE}
# FISH          {fluorescent in situ hybridization, GENERAL ENGLISH}
# FSH           {fascioscapulohumeral muscular dystrophy, follicle-stimulating hormone, Fairview Southdale Hospital}
# GT            {guttae:GGT, gamma-glutamyltransferase:GGT, gutta, glucose tolerance, glutamyl transpeptidase, gastrostomy tube}
# IA            {(type) IA, (stage) IA, (status) IA, (class) IA, (grade) IA, transient ischemic attack:TIA, Iowa, intraarterial, UNSURED SENSE}
# IB            {intravenous:IV, UNSURED SENSE, (status) IB, (cycle) IB, (type) IB, international baccalaureate, (stage) IB, (grade) IB, interferon beta}
# IM            {UNSURED SENSE, intramuscular, intramedullary}
# IR            {infrared, internal rotation, interventional radiology, immediate-release, UNSURED SENSE}
# IT            {idiopathic thrombocytopenic purpura:ITP, (drug) IT, GENERAL ENGLISH, information technology, ischial tuberosity, pravastatin or atorvastatin evaluation and infection therapy, iliotibial, intrathecal, intertrochanteric, immature-to-total neutrophil, UNSURED SENSE, inspiratory time}
# ITP           {idiopathic thrombocytopenic purpura}
# IVF           {inferior vena cava:IVC, UNSURED SENSE, intravenous fluid, in vitro fertilization}
# LA            {Louisiana, left atrial, antinuclear antibody:ANA, long-acting, UNSURED SENSE, Los Angeles}
# LE            {lower extremity, left ventricle:LV, long-acting:LA, leukocyte esterase, lupus erythematosus, sinemet-levodopa, UNSURED SENSE, NAME, lymphedema}
# MOM           {milk of magnesia, Mall of America:MOA, multiples of median, GENERAL ENGLISH}
# MP            {mercaptopurine, (device) MP, metacarpophalangeal, metatarsophalangeal, (drug) MP, mesangial proliferative, military police, menstrual period, metabolic panel, milligram:mg, metatarsophalangeal/metacarpophalangeal, nurse practitioner:NP, metarsophalangeal, UNSURED SENSE}
# MR            {mental retardation, GENERAL ENGLISH, magnetic resonance, mitral regurgitation, medical record, myocardial infarction:MI}
# MS            {GENERAL ENGLISH, master of science, mitral stenosis, multiple sclerosis, musculoskeletal, medical student, morphine sulfate, UNSURED SENSE, NAME, (drug) MS}
# MSSA          {modified selective severity assessment, methicillin-susceptible Staphylococcus aureus}
# NAD           {no acute distress, nothing abnormal detected}
# NP            {nurse practitioner, (drug) NP, nasopharyngeal, UNSURED SENSE, natriuretic peptide, nasopharynx}
# OP            {ova and parasites, ophthalmic, occiput posterior, operative, oblique presentation/occiput posterior, outpatient, oropharynx, UNSURED SENSE}
# OR            {UNSURED SENSE, GENERAL ENGLISH, (drug) OR, operating room}
# OTC           {over the counter, ornithine transcarbamoylase}
# PA            {pulmonary embolus:PE, pulmonary artery, physician associates, UNSURED SENSE, posterior-anterior, tissue plasminogen activator:TPA, physician assistant, pulmonary auscultation}
# PAC           {premature atrial contraction, physician assistant certification, patient-controlled analgesia:PCA, post anesthesia care, picture archiving communication, pulmonary artery catheter, prostate-specific antigen:PSA, pulmonary arterial concentration, UNSURED SENSE, (drug) PAC}
# PCP           {patient-controlled analgesia:PCA, Pneumocystis jiroveci pneumonia, primary care physician, UNSURED SENSE, phencyclidine}
# PD            {peritoneal dialysis, police department, posterior descending, UNSURED SENSE, (device) PD, pulmonary embolus:PE, prism diopter, pancreatic duct, purified protein derivative:PPD, phosphate dehydrogenase, dorsalis pedis:DP, Parkinson disease, (drug) PD, patent ductus, personality disorder}
# PDA           {patient-controlled analgesia:PCA, patent ductus arteriosus, posterior descending artery}
# PE            {UNSURED SENSE, pleural effusion, pulmonary embolus, pressure equalization}
# PM            {UNSURED SENSE, metacarpophalangeal:MP, physical medicine and rehabilitation:PMR, afternoon}
# PR            {progesterone receptor, (drug) PR, per rectum, pulse rate, pulmonary regurgitation, UNSURED SENSE, pr interval}
# PT            {prothrombin, UNSURED SENSE, physical therapy, posterior tibial, prothrombin time}
# RA            {rheumatoid arthritis, retinoic acid, right atrium, UNSURED SENSE, room air}
# RT            {radiation therapy, retrograde tachycardia, (drug) RT, right, UNSURED SENSE, respiratory therapy, NAME, respiratory therapist}
# SA            {American Society of Anesthesiologists:ASA, saturation, UNSURED SENSE, methicillin-susceptible Staphylococcus aureus:MSSA, MISTAKE:Oncotype DX, sinuatrial, sinus arrest, slow acting/sustained action}
# SBP           {spontaneous bacterial peritonitis, systolic blood pressure}
# SMA           {smooth muscle actin, smooth muscle antibody, UNSURED SENSE, superior mesenteric artery, spinal muscular atrophy, sequential multiple autoanalyzer}
# SS            {UNSURED SENSE, single strength, sickle cell genotype SS}
# T1            {tumor stage 1, thoracic (level) 1, term 1, type 1 (diabetes mellitus), UNSURED SENSE, T1 (MRI)}
# T2            {S2 (heart sound):S2, tumor stage 2, T2 (MRI), term 2, thoracic (level) 2, T2 Nodes, UNSURED SENSE}
# T3            {term 3, triiodothyronine, UNSURED SENSE, tumor stage 3, T3 (ECG pattern), thoracic (level) 3}
# T4            {thoracic (level) 4, tumor stage 4, thyroxine}
# US            {UNSURED SENSE, ultrasound, United States, GENERAL ENGLISH}
# VAD           {ventricular assist device, vincristine adriamycin and dexamethasone, video-assisted thoracic surgery:VATS, vascular access device, UNSURED SENSE}
# VBG           {venous blood gas, vertical banded gastroplasty}

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_recall_fscore_support
np.set_printoptions(threshold=np.nan)

# %%
def find_acronym_full_form(sentence):
    df = pd.read_csv("Data/PatientNotes_acronym_longform.csv")
    acronym_list = list(df.abbreviation.unique())
    positive_acronym = []
    for word in sentence.split():
        if word in acronym_list:
            positive_acronym.append(word)
    positive_acronym_strength = {}
    for x in positive_acronym:
        positive_acronym_strength[x] = len(group_df.loc[x]['long_form'])
    #print(positive_acronym_strength)
    acronym_found = sorted(positive_acronym_strength, key=positive_acronym_strength.get, reverse=False)
    #print(acronym_found)
    
    #print([word for word in vector_breakage(sentence) if word not in acronym_found])
    sentence = ''.join([word for word in sentence if word not in acronym_found])
    for item in acronym_found:
        df_slice = df[df.abbreviation==item]
        y = df_slice.long_form
        X = list([sentence_vector(x) for x in df_slice.sentence])
        #X_train, X_test, y_train, y_test = train_test_split(X, y)
        clf = SVC(C=1.0, kernel='linear', degree=1,probability = True).fit(X, y)
        print(clf.predict_proba(sentence_vector(sentence).reshape(1,-1)))
        return clf.predict(sentence_vector(sentence).reshape(1, -1))[0]

# %%
find_acronym_full_form('MS is a disease in which the immune system eats away at the protective covering of nerves')
# Out:
# [[0.00285257 0.00191455 0.00292538 0.00562273 0.00291552 0.00332507
#   0.00259324 0.02222043 0.95301789 0.00261262]]
# 'multiple sclerosis'

# %% [markdown]
# ## Test

# %%
find_acronym_full_form('lung malignant CA')
# Out:
# [[0.01159068 0.01242014 0.02298533 0.95300385]]
# 'carbohydrate antigen'

# %%
print(model.most_similar(positive = 'effusion', topn = 6))
# Out:
# /anaconda/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('effusions', 0.8661322593688965), ('pleural', 0.7674405574798584), ('pericardial', 0.7196462154388428), ('pleuro-pericardial', 0.7094818353652954), ('Pleuropericardial', 0.7049542665481567), ('transudative', 0.7045389413833618)]
